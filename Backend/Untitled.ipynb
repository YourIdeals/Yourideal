# %%
import bcrypt
password = "Tanya18"  # your chosen password
hashed = bcrypt.hashpw(password.encode(), bcrypt.gensalt(rounds=12))
print(hashed.decode())
# Out:
# $2b$12$iB3w75head8b2fnxuvWVBOmGyte0nH8xjPl6GlWKaoOBnABcAlMoa
